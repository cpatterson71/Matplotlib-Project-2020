# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# %%
study_results.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     b128          0                45.0                 0
# 1     f932          0                45.0                 0
# 2     g107          0                45.0                 0
# 3     a457          0                45.0                 0
# 4     c819          0                45.0                 0

# %%
mouse_metadata.head()
# Out:
#   Mouse ID Drug Regimen     Sex  Age_months  Weight (g)
# 0     k403     Ramicane    Male          21          16
# 1     s185    Capomulin  Female           3          17
# 2     x401    Capomulin  Female          16          15
# 3     m601    Capomulin    Male          22          17
# 4     g791     Ramicane    Male          11          16

# %%
# Combine the data into a single dataset
merged_df = pd.merge(mouse_metadata, study_results, how='inner', on ='Mouse ID')


# Display the data table for preview
merged_df.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Checking the number of mice.
number_of_mice = merged_df['Mouse ID'].count()
number_of_mice
# Out:
# 1893

# %%
merged_df.dtypes
# Out:
# Mouse ID               object
# Drug Regimen           object
# Sex                    object
# Age_months              int64
# Weight (g)              int64
# Timepoint               int64
# Tumor Volume (mm3)    float64
# Metastatic Sites        int64
# dtype: object

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_timepoint = merged_df.duplicated(subset= 'Mouse ID')
duplicate_timepoint.head()
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# dtype: bool

# %%
# Optional: Get all the data for the duplicate mouse ID.

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
cleaned_df = merged_df.drop_duplicates(subset='Mouse ID')

cleaned_df_groupedby = cleaned_df.groupby(['Drug Regimen'])
cleaned_df_groupedby.head()
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0       k403     Ramicane    Male          21          16          0
# 10      s185    Capomulin  Female           3          17          0
# 20      x401    Capomulin  Female          16          15          0
# 30      m601    Capomulin    Male          22          17          0
# 40      g791     Ramicane    Male          11          16          0
# 50      s508     Ramicane    Male           1          17          0
# 60      f966    Capomulin    Male          16          17          0
# 65      m546     Ramicane    Male          18          16          0
# 75      z578     Ramicane    Male          11          16          0
# 95      u364    Capomulin    Male          18          17          0
# 454     a203    Infubinol  Female          20          23          0
# 464     a251    Infubinol  Female          21          25          0
# 474     a262      Placebo  Female          17          29          0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
number_of_mice2 = cleaned_df['Mouse ID'].count()
number_of_mice2
# Out:
# 249

# %% [markdown]
# ## Summary Statistics

# %%
merged_df_grouped = merged_df.groupby(['Drug Regimen'])
print(merged_df_grouped)
merged_df_grouped.head()
# Out:
# ...
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0       k403     Ramicane    Male          21          16          0
# 1       k403     Ramicane    Male          21          16          5
# 2       k403     Ramicane    Male          21          16         10
# 3       k403     Ramicane    Male          21          16         15
# 4       k403     Ramicane    Male          21          16         20
# 10      s185    Capomulin  Female           3          17          0
# 11      s185    Capomulin  Female           3          17          5
# 12      s185    Capomulin  Female           3          17         10
# 13      s185    Capomulin  Female           3          17         15
# 14      s185    Capomulin  Female           3          17         20
# 454     a203    Infubinol  Female          20          23          0
# 455     a203    Infubinol  Female          20          23          5
# 456     a203    Infubinol  Female          20          23         10
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
mean_tumor_volume = round(merged_df['Tumor Volume (mm3)'].mean(),2)
median_tumor_volume = round(merged_df['Tumor Volume (mm3)'].median(),2)
std_tumor_volume = round(merged_df['Tumor Volume (mm3)'].std(),2)
sem_tumor_volume = round(merged_df['Tumor Volume (mm3)'].sem(),2)

# This method is the most straighforward, creating multiple series and putting them all together at the end.
summary_stats_total = pd.DataFrame({'Mean Tumor Volume is': [mean_tumor_volume],
                                  'Median Tumor Volume is': [median_tumor_volume],
                                  'Standard Deviation of Tumor Volume is ': [std_tumor_volume],
                                   'SEM of Tumor Volume': [sem_tumor_volume]})
summary_stats_total.head()
# Out:
#    Mean Tumor Volume is  Median Tumor Volume is  \
# 0                 50.45                   48.95
#
#    Standard Deviation of Tumor Volume is   SEM of Tumor Volume
# 0                                    8.89                  0.2

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
grouped_df_by_regimen = merged_df.groupby(['Tumor Volume (mm3)'])


# This method produces everything in a single groupby function
grouped_df_by_regimen['Drug Regimen'].describe()
# Out:
#                    count unique        top freq
# Tumor Volume (mm3)
# 22.050126              1      1   Ramicane    1
# 23.343598              1      1  Capomulin    1
# 24.365505              1      1   Ramicane    1
# 25.472143              1      1  Capomulin    1
# 26.546993              1      1   Ramicane    1
# 28.167397              1      1  Capomulin    1
# 28.328531              1      1  Capomulin    1
# 28.430964              1      1  Capomulin    1
# 28.484033              1      1  Capomulin    1
# 29.128472              1      1   Ramicane    1
# 30.206825              1      1  Capomulin    1
# 30.276232              1      1   Ramicane    1
# 30.485985              1      1  Capomulin    1
# 30.564625              1      1   Ramicane    1
# 30.638696              1      1   Ramicane    1
# 30.834357              1      1  Capomulin    1
# 30.960392              1      1   Ramicane    1
# 31.001861              1      1   Ramicane    1
# ...

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pandas. 
labels = ['Capomulin', 'Ceftamin', 'Infubinol', 'Ketapril', 'Naftisol', 'Placebo', 'Propriva', 'Ramicane', 'Stelasyn', 'Zoniferol']
count = cleaned_df_groupedby['Drug Regimen'].value_counts()
explode = (0.1,0,0,0)

plt.pie(count, labels=labels, autopct='%1.1f%%', shadow=True, startangle=140)

plt.title("Percentage of Mice Treated by Medication")

plt.show()

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pyplot.
x_axis = len(merged_df['Mouse ID'])
y_axis = merged_df['Timepoint']

plt.bar(y_axis,x_axis, color='r', align='center')
plt.xlabel('Timepoint')
plt.ylabel('Number of Mice')
plt.title('Number of Mice per Timepoint (Months)')

plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
gender = merged_df['Sex'].value_counts()

gender.plot(kind='pie', figsize=(8,8), subplots=True)

plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
gender = merged_df['Sex'].value_counts()
labels = ['Male', 'Female']

plt.pie(gender, labels=labels, autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Percentage of Male and Female Mice")
# Out:
# Text(0.5, 1.0, 'Percentage of Male and Female Mice')

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
short_merged_df = merged_df.loc[:,['Drug Regimen','Timepoint', 'Tumor Volume (mm3)','Weight (g)']]
capomulin_summary = short_merged_df.loc[(short_merged_df['Drug Regimen'] == 'Capomulin')]
print(capomulin_summary)
# Out:
#      Drug Regimen  Timepoint  Tumor Volume (mm3)  Weight (g)
# 10      Capomulin          0           45.000000          17
# 11      Capomulin          5           43.878496          17
# 12      Capomulin         10           37.614948          17
# 13      Capomulin         15           38.177232          17
# 14      Capomulin         20           36.866876          17
# 15      Capomulin         25           33.949940          17
# 16      Capomulin         30           32.959671          17
# 17      Capomulin         35           28.328531          17
# 18      Capomulin         40           25.472143          17
# 19      Capomulin         45           23.343598          17
# 20      Capomulin          0           45.000000          15
# 21      Capomulin          5           45.473753          15
# 22      Capomulin         10           39.113891          15
# 23      Capomulin         15           39.776250          15
# ...

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
times = capomulin_summary['Timepoint']
tumor_volume = capomulin_summary['Tumor Volume (mm3)']

fig1, ax1 = plt.subplots()
ax1.set_title('Tumor Volumes over Time for Capomulin')
ax1.set_ylabel('Tumor Volume')
ax1.boxplot(tumor_volume)
plt.show()

# %%
infubinol_summary = short_merged_df.loc[(short_merged_df['Drug Regimen'] == 'Infubinol')]
times = infubinol_summary['Timepoint']
tumor_volume = infubinol_summary['Tumor Volume (mm3)']

fig1, ax1 = plt.subplots()
ax1.set_title('Tumor Volumes over Time for Infubinol')
ax1.set_ylabel('Tumor Volume')
ax1.boxplot(tumor_volume)
plt.show()

# %%
ramicane_summary = short_merged_df.loc[(short_merged_df['Drug Regimen'] == 'Ramicane')]
times = ramicane_summary['Timepoint']
tumor_volume = ramicane_summary['Tumor Volume (mm3)']

fig1, ax1 = plt.subplots()
ax1.set_title('Tumor Volumes over Time for Ramicane')
ax1.set_ylabel('Tumor Volume')
ax1.boxplot(tumor_volume)
plt.show()

# %%
ceftamin_summary = short_merged_df.loc[(short_merged_df['Drug Regimen'] == 'Ceftamin')]
times = ceftamin_summary['Timepoint']
tumor_volume = ceftamin_summary['Tumor Volume (mm3)']

fig1, ax1 = plt.subplots()
ax1.set_title('Tumor Volumes over Time for Ceftamin')
ax1.set_ylabel('Tumor Volume')
ax1.boxplot(tumor_volume)
plt.show()

# %%
# Put treatments into a list for for loop (and later for plot labels)
labels = []

for drugs in cleaned_df_groupedby:
    labels.append(cleaned_df_groupedby['Drug Regimen'])
    pass

# Create empty list to fill with tumor vol data (for plotting)
volume_data = []

for volume in cleaned_df_groupedby:
    volume_data.append(cleaned_df_groupedby['Tumor Volume (mm3)'])
    pass

volume_data_df = pd.DataFrame(volume_data)
print(volume_data_df)
# Out:
#                                                    0  \
# 0  (Capomulin, [45.0, 45.0, 45.0, 45.0, 45.0, 45....
# 1  (Capomulin, [45.0, 45.0, 45.0, 45.0, 45.0, 45....
# 2  (Capomulin, [45.0, 45.0, 45.0, 45.0, 45.0, 45....
# 3  (Capomulin, [45.0, 45.0, 45.0, 45.0, 45.0, 45....
# 4  (Capomulin, [45.0, 45.0, 45.0, 45.0, 45.0, 45....
# 5  (Capomulin, [45.0, 45.0, 45.0, 45.0, 45.0, 45....
# 6  (Capomulin, [45.0, 45.0, 45.0, 45.0, 45.0, 45....
# 7  (Capomulin, [45.0, 45.0, 45.0, 45.0, 45.0, 45....
# 8  (Capomulin, [45.0, 45.0, 45.0, 45.0, 45.0, 45....
# 9  (Capomulin, [45.0, 45.0, 45.0, 45.0, 45.0, 45....
#
#                                                    1  \
# 0  (Ceftamin, [45.0, 45.0, 45.0, 45.0, 45.0, 45.0...
# 1  (Ceftamin, [45.0, 45.0, 45.0, 45.0, 45.0, 45.0...
# 2  (Ceftamin, [45.0, 45.0, 45.0, 45.0, 45.0, 45.0...
# 3  (Ceftamin, [45.0, 45.0, 45.0, 45.0, 45.0, 45.0...
# 4  (Ceftamin, [45.0, 45.0, 45.0, 45.0, 45.0, 45.0...
# 5  (Ceftamin, [45.0, 45.0, 45.0, 45.0, 45.0, 45.0...
# ...

# %%
quartiles = short_merged_df['Tumor Volume (mm3)'].quantile([.25,.5,.75])
lowerq = quartiles[.25]
upperq = round(quartiles[.75],2)
iqr = round(upperq-lowerq,2)

print(f"The lower quartile of tumor volume is: {lowerq}")
print(f"The upper quartile of tumor volume is: {upperq}")
print(f"The interquartile range of tumor volume is: {iqr}")
print(f"The the median of tumor volume is: {quartiles[.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
# Out:
# The lower quartile of tumor volume is: 45.0
# The upper quartile of tumor volume is: 56.29
# The interquartile range of tumor volume is: 11.29
# The the median of tumor volume is: 48.95147442
# Values below 28.065 could be outliers.
# Values above 73.225 could be outliers.

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
Tumor_Volume = short_merged_df['Tumor Volume (mm3)']

ig1, ax1 = plt.subplots()
ax1.set_title('Tumor Volumes over Time')
ax1.set_ylabel('Tumor Volume')
ax1.boxplot(tumor_volume)
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
line_summary = capomulin_summary.set_index(['Drug Regimen'])
line_summary
# Out:
#               Timepoint  Tumor Volume (mm3)  Weight (g)
# Drug Regimen
# Capomulin             0           45.000000          17
# Capomulin             5           43.878496          17
# Capomulin            10           37.614948          17
# Capomulin            15           38.177232          17
# Capomulin            20           36.866876          17
# Capomulin            25           33.949940          17
# Capomulin            30           32.959671          17
# Capomulin            35           28.328531          17
# Capomulin            40           25.472143          17
# Capomulin            45           23.343598          17
# Capomulin             0           45.000000          15
# Capomulin             5           45.473753          15
# Capomulin            10           39.113891          15
# Capomulin            15           39.776250          15
# Capomulin            20           36.065835          15
# ...

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin

x_axis = line_summary['Timepoint']

y_axis = []
for time in x_axis:
    y_axis.append(line_summary['Tumor Volume (mm3)'].mean())


plt.plot(x_axis, y_axis, marker='o', color='blue', label='Capomulin')
plt.xlabel('Timepoints')
plt.ylabel('Tumor Volume (mm3)')
plt.title('Timepoint versus Tumor Volume for Capomulin')
plt.legend(loc='best')
plt.show()

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen

y_axis = round(line_summary['Tumor Volume (mm3)'],2)
x_axis = line_summary['Weight (g)']

plt.xlabel('Weight of Mouse (gm)')
plt.ylabel('Tumor Volume (mm3)')

plt.scatter(x_axis, y_axis, marker='o', facecolors='blue', edgecolors='black')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
# correlation

# %%
#Regression
